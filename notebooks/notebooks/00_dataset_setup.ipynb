# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("wordsforthewise/lending-club")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/purvapradippatil/.cache/kagglehub/datasets/wordsforthewise/lending-club/versions/3

# %%
import os

os.listdir(path)
# Out:
# ['rejected_2007_to_2018q4.csv',
#  'accepted_2007_to_2018q4.csv',
#  'rejected_2007_to_2018Q4.csv.gz',
#  'accepted_2007_to_2018Q4.csv.gz']

# %%
import os

print(path)
print(os.listdir(path))
# Out:
# /Users/purvapradippatil/.cache/kagglehub/datasets/wordsforthewise/lending-club/versions/3
# ['rejected_2007_to_2018q4.csv', 'accepted_2007_to_2018q4.csv', 'rejected_2007_to_2018Q4.csv.gz', 'accepted_2007_to_2018Q4.csv.gz']

# %%
folder = os.path.join(path, "accepted_2007_to_2018Q4.csv")

print(os.listdir(folder))
# Out:
# ['accepted_2007_to_2018Q4.csv']

# %%
import os

item = os.path.join(path, "accepted_2007_to_2018Q4.csv")

print("Is file:", os.path.isfile(item))
print("Is directory:", os.path.isdir(item))
# Out:
# Is file: False
# Is directory: True

# %%
import os

for root, dirs, files in os.walk(path):
    print("ROOT:", root)
    print("FILES:", files)
    print("-" * 50)
# Out:
# ROOT: /Users/purvapradippatil/.cache/kagglehub/datasets/wordsforthewise/lending-club/versions/3
# FILES: ['rejected_2007_to_2018Q4.csv.gz', 'accepted_2007_to_2018Q4.csv.gz']
# --------------------------------------------------
# ROOT: /Users/purvapradippatil/.cache/kagglehub/datasets/wordsforthewise/lending-club/versions/3/rejected_2007_to_2018q4.csv
# FILES: ['rejected_2007_to_2018Q4.csv']
# --------------------------------------------------
# ROOT: /Users/purvapradippatil/.cache/kagglehub/datasets/wordsforthewise/lending-club/versions/3/accepted_2007_to_2018q4.csv
# FILES: ['accepted_2007_to_2018Q4.csv']
# --------------------------------------------------

# %%
import os
import pandas as pd

file_path = os.path.join(
    path,
    "accepted_2007_to_2018q4.csv",
    "accepted_2007_to_2018Q4.csv"
)

print(file_path)

df = pd.read_csv(file_path, low_memory=False)
df.to_csv("/Users/purvapradippatil/prep/Credit-Risk-Portfolio-Analytics/data/raw/loan.csv", index=False)
df.head()
# Out:
# /Users/purvapradippatil/.cache/kagglehub/datasets/wordsforthewise/lending-club/versions/3/accepted_2007_to_2018q4.csv/accepted_2007_to_2018Q4.csv
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# 1     11.99       820.28     C        C1  ...                            NaN
# 2     10.78       432.66     B        B4  ...                            NaN
# ...
